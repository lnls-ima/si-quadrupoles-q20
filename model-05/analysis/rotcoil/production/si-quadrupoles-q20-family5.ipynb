# %% [markdown]
# # Rotating Coild Data Analysis for SI Q20-Fam5 Magnets

# %% [markdown]
# ## Import libraries and Load measurement data

# %%
import sys
import numpy as np
import matplotlib
matplotlib.use('Qt5Agg')

# %matplotlib notebook

import matplotlib.pyplot as plt
from lnls.rotcoil import *

# %%
# Define serial numbers, one for each magnet

serials = [
    '004', '008', '017', '019', '020', '024', '025', '096', '097', '101',
    '103', '104', '134', '135', '148',
]

# Load all data
RotCoilMeas_SIQuadQ20.family_folder = 'family_5/'
data = MagnetsAnalysis(RotCoilMeas_SIQuadQ20, serials)
data.init()

# Print info
data.print_info()
# Out:
# index: 00, serial_number: 004, data sets: ['M1']
# index: 01, serial_number: 008, data sets: ['M1']
# index: 02, serial_number: 017, data sets: ['M1']
# index: 03, serial_number: 019, data sets: ['M1']
# index: 04, serial_number: 020, data sets: ['M1']
# index: 05, serial_number: 024, data sets: ['M1']
# index: 06, serial_number: 025, data sets: ['M1']
# index: 07, serial_number: 096, data sets: ['M1']
# index: 08, serial_number: 097, data sets: ['M1']
# index: 09, serial_number: 101, data sets: ['M1']
# index: 10, serial_number: 103, data sets: ['M1']
# index: 11, serial_number: 104, data sets: ['M1_orig', 'M1']
# index: 12, serial_number: 134, data sets: ['M1']
# index: 13, serial_number: 135, data sets: ['M1']
# index: 14, serial_number: 148, data sets: ['M1_orig', 'M1']

# %% [markdown]
# ## Maximum Integrated Quadrupole

# %%
# gets integrated strength at maximum current for all magnets
data.main_intmpole_at_max_current('M1')
# Out:
# index:00, serial:004, idx:12, max_current:  +157.5187 [A], diff_spec: +0.10 [%]
# index:01, serial:008, idx:12, max_current:  +157.5202 [A], diff_spec: +0.28 [%]
# index:02, serial:017, idx:12, max_current:  +157.5185 [A], diff_spec: +0.19 [%]
# index:03, serial:019, idx:12, max_current:  +157.5199 [A], diff_spec: +0.09 [%]
# index:04, serial:020, idx:12, max_current:  +157.5173 [A], diff_spec: +0.23 [%]
# index:05, serial:024, idx:12, max_current:  +157.5194 [A], diff_spec: +0.12 [%]
# index:06, serial:025, idx:12, max_current:  +157.5181 [A], diff_spec: +0.12 [%]
# index:07, serial:096, idx:12, max_current:  +157.5173 [A], diff_spec: +0.03 [%]
# index:08, serial:097, idx:12, max_current:  +157.5177 [A], diff_spec: +0.01 [%]
# index:09, serial:101, idx:12, max_current:  +157.5173 [A], diff_spec: +0.04 [%]
# index:10, serial:103, idx:12, max_current:  +157.5179 [A], diff_spec: -0.01 [%]
# index:11, serial:104, idx:12, max_current:  +157.5209 [A], diff_spec: +0.01 [%]
# index:12, serial:134, idx:12, max_current:  +157.5173 [A], diff_spec: +0.03 [%]
# index:13, serial:135, idx:12, max_current:  +157.5192 [A], diff_spec: +0.02 [%]
# index:14, serial:148, idx:12, max_current:  +157.5189 [A], diff_spec: +0.04 [%]

# %%
# plot data comparison with spec
plt.figure()
data.main_intmpole_at_max_current_plot(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Magnetic Center

# %%
# Horizontal center for all magnets x currents
plt.figure()
data.magnetic_center_direction_plot('M1', 'X', plt)
plt.show()

# Vertical center for all magnets y currents
plt.figure()
data.magnetic_center_direction_plot('M1', 'Y', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Horizontal center at maximum current [um]: +6.28 ± 6.80
# <img src="data:image/png;base64,..." width="640">
# Vertical center at maximum current [um]: +5.30 ± 3.49

# %%
# Horizontal and vertical positions of all magnets
plt.figure()
data.magnetic_center_plot('M1', plt)
plt.show()

# Transverse plane positions
plt.figure()
data.magnetic_center_transverse_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Ramp Up

# %%
# Plot rampup integrated strength of main multipole and compare it to nominal values and maximum spec

plt.figure()
data.rampup_excitation_curve_plot('M1', plt)
plt.show()

# Print currents for nominal strengths
print()
d = data.tmpl.get_nominal_main_intmpole_values(3.0)
for fam, gl in d.items():
    c = data.tmpl.rampup_main_mpole_2_curr('M1', gl)
    print('{:<15s}: {:05.1f} A'.format(fam, c))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Nominal Integrated Quadrupole [T]:
# SI-Fam:MA-QFA   : -7.151253
# SI-Fam:MA-Q1    : -5.635511
# SI-Fam:MA-Q2    : -8.690641
# SI-Fam:MA-Q3    : -6.475734
# SI-Fam:MA-Q4    : -7.873274
#
# SI-Fam:MA-QFA  : 121.5 A
# SI-Fam:MA-Q1   : 095.4 A
# SI-Fam:MA-Q2   : 149.9 A
# SI-Fam:MA-Q3   : 109.8 A
# SI-Fam:MA-Q4   : 134.4 A

# %%
# Plot rampup dispersion amongst magnets

# Q20-099 is off.

plt.figure()
data.rampup_excitation_curve_dispersion_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Print random integrated main strength for various currents

data.rampup_excitation_curve_rms_error_print('M1')
# Out:
# current 00:   +0.001 [A], rms_error:  5.0222 [%], max_error: 10.1362 [%]
# current 01:   +1.995 [A], rms_error:  0.9456 [%], max_error:  2.0917 [%]
# current 02:   +3.998 [A], rms_error:  0.4379 [%], max_error:  0.9710 [%]
# current 03:   +5.997 [A], rms_error:  0.2622 [%], max_error:  0.5522 [%]
# current 04:   +7.996 [A], rms_error:  0.1829 [%], max_error:  0.3518 [%]
# current 05:   +9.996 [A], rms_error:  0.1413 [%], max_error:  0.2592 [%]
# current 06:  +29.996 [A], rms_error:  0.0717 [%], max_error:  0.1576 [%]
# current 07:  +49.995 [A], rms_error:  0.0556 [%], max_error:  0.1364 [%]
# current 08:  +69.995 [A], rms_error:  0.0530 [%], max_error:  0.1344 [%]
# current 09:  +89.999 [A], rms_error:  0.0636 [%], max_error:  0.1498 [%]
# current 10: +109.997 [A], rms_error:  0.0948 [%], max_error:  0.1890 [%]
# current 11: +129.996 [A], rms_error:  0.1266 [%], max_error:  0.2329 [%]
# current 12: +157.519 [A], rms_error:  0.0852 [%], max_error:  0.1948 [%]

# %%
# Plot Integrated Quadrupole Error for maximum current

plt.figure()
data.rampup_excitation_curve_rms_error_plot(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Gradient Roll Error

# %%
# Q1, I=95A
curr_idx = 9  
plt.figure()
spec, avg, std = data.rotation_error_plot('M1', plt, curr_idx)
print('Angle error (Spec): {:+.3f} mrad'.format(spec))
print('Angle error (Avg) : {:+.3f} mrad'.format(avg))
print('Angle error (Std) : {:+.3f} mrad'.format(std))

# Q3, I=110A
curr_idx = 10  
plt.figure()
spec, avg, std = data.rotation_error_plot('M1', plt, curr_idx)
print('Angle error (Spec): {:+.3f} mrad'.format(spec))
print('Angle error (Avg) : {:+.3f} mrad'.format(avg))
print('Angle error (Std) : {:+.3f} mrad'.format(std))

# QFA I=121A and Q4 I=134A
curr_idx = 11  
plt.figure()
spec, avg, std = data.rotation_error_plot('M1', plt, curr_idx)
print('Angle error (Spec): {:+.3f} mrad'.format(spec))
print('Angle error (Avg) : {:+.3f} mrad'.format(avg))
print('Angle error (Std) : {:+.3f} mrad'.format(std))

# Q2, I=150A
curr_idx = 12  
plt.figure()
spec, avg, std = data.rotation_error_plot('M1', plt, curr_idx)
print('Angle error (Spec): {:+.3f} mrad'.format(spec))
print('Angle error (Avg) : {:+.3f} mrad'.format(avg))
print('Angle error (Std) : {:+.3f} mrad'.format(std))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Angle error (Spec): +0.300 mrad
# Angle error (Avg) : +0.089 mrad
# Angle error (Std) : +0.103 mrad
# <img src="data:image/png;base64,..." width="640">
# Angle error (Spec): +0.300 mrad
# Angle error (Avg) : +0.086 mrad
# Angle error (Std) : +0.103 mrad
# <img src="data:image/png;base64,..." width="640">
# Angle error (Spec): +0.300 mrad
# Angle error (Avg) : +0.085 mrad
# Angle error (Std) : +0.103 mrad
# <img src="data:image/png;base64,..." width="640">
# Angle error (Spec): +0.300 mrad
# Angle error (Avg) : +0.082 mrad
# Angle error (Std) : +0.103 mrad

# %% [markdown]
# ## Hysteresis

# %%
# Absolute
plt.figure()
data.hysteresis_absolute_plot('M1', plt)
plt.show()

# Relative
plt.figure()
data.hysteresis_relative_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Save Excitation Data Files

# %%
# save average excitation data to file

data.save_excdata_average('M1')

# %%
# save excitation data of all magnets to separate files
data.save_excdata_individuals('M1')

# %% [markdown]
# ## Multipoles

# %%
# Horizontal kick

# Q1, I=95A
curr_idx = 9  
plt.figure()
data.multipole_errors_kickx_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()

# Q2, I=110A
curr_idx = 10  
plt.figure()
data.multipole_errors_kickx_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()

# QFA, I=121A and Q4 I=134A
curr_idx = 11  
plt.figure()
data.multipole_errors_kickx_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()

# Q4 I=150A
curr_idx = 12  
plt.figure()
data.multipole_errors_kickx_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# Vertical kick

# Q1, I=95A
curr_idx = 9  
plt.figure()
data.multipole_errors_kicky_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()

# Q2, I=110A
curr_idx = 10  
plt.figure()
data.multipole_errors_kicky_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()

# QFA, I=121A and Q4 I=134A
curr_idx = 11  
plt.figure()
data.multipole_errors_kicky_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()

# Q4 I=150A
curr_idx = 12  
plt.figure()
data.multipole_errors_kicky_plot('M1', plt, curr_idx=curr_idx, energy=3.0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Magnets Sorting

# %%
med = 'M1'
print('Rampup')
c, gl = data.tmpl.get_rampup(med)
for i in range(len(c)):
    print('{:02d}: I = {:8.4f} A => GL = {:+.4f} T'.format(i, c[i], gl[i]))
# Out:
# Rampup
# 00: I =   0.0010 A => GL = -0.0387 T
# 01: I =   1.9962 A => GL = -0.1504 T
# 02: I =   3.9987 A => GL = -0.2635 T
# 03: I =   5.9978 A => GL = -0.3771 T
# 04: I =   7.9961 A => GL = -0.4913 T
# 05: I =   9.9962 A => GL = -0.6061 T
# 06: I =  29.9966 A => GL = -1.7737 T
# 07: I =  49.9948 A => GL = -2.9555 T
# 08: I =  69.9952 A => GL = -4.1394 T
# 09: I =  89.9986 A => GL = -5.3200 T
# 10: I = 109.9963 A => GL = -6.4898 T
# 11: I = 129.9962 A => GL = -7.6392 T
# 12: I = 157.5187 A => GL = -9.0956 T

# %%
# Print README Files

currents, _ = data.tmpl.get_rampup('M1')
stdout = sys.stdout
for cidx in range(1,len(currents)):
    sys.stdout = open('README-FAM5-{:.0f}A.md'.format(currents[cidx]), 'w')
    data.readme_print('M1', cidx)
    sys.stdout.flush()
sys.stdout = stdout

# %%
# Print Multipoles Files

currents, _ = data.tmpl.get_rampup('M1')
stdout = sys.stdout
for cidx in range(1,len(currents)):
    sys.stdout = open('MULTIPOLES-FAM5-{:.0f}A.txt'.format(currents[cidx]), 'w')
    data.readme_multipoles_print('M1', cidx)
    sys.stdout.flush()
sys.stdout = stdout
